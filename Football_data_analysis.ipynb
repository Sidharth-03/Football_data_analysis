# %% [markdown]
# Importing required libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import ipywidgets as widgets
import plotly.graph_objects as go

# %% [markdown]
# Creating a function to scrape the website

# %%
def scrape(url):
  page=requests.get(url)
  soup=BeautifulSoup(page.text,'lxml')
  #scraping the table
  table=soup.find('table',{'id':'results{}91_overall'.format(url[29:38])})
  header=[]
  #getting the column names of the table
  for i in table.find_all('th'):
    title=i.text.strip()
    header.append(title)
  header=header[:19]
  #creating a dataframe with the scraped column names
  df=pd.DataFrame(columns=header)
  #getting the data of the table and adding it to the dataframe
  for row in table.find_all('tr')[1:]:
    data=row.find_all('td')
    row_data1=[len(df)+1]
    row_data2=[td.text.strip() for td in data]
    row_data=row_data1+row_data2
    print(row_data)
    df.loc[len(df)]=row_data
  return df
df=scrape("https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats")
# Out:
# [1, 'Manchester City', '38', '29', '6', '3', '99', '26', '+73', '93', '2.45', '96.6', '26.0', '+70.5', '+1.86', '52,774', 'Kevin De Bruyne - 15', 'Ederson', '→ Champions League via league finish']
# [2, 'Liverpool', '38', '28', '8', '2', '94', '26', '+68', '92', '2.42', '95.1', '37.3', '+57.8', '+1.52', '53,352', 'Mohamed Salah - 23', 'Alisson', '→ Champions League via league finish']
# [3, 'Chelsea', '38', '21', '11', '6', '76', '33', '+43', '74', '1.95', '70.7', '38.3', '+32.5', '+0.86', '36,443', 'Mason Mount - 11', 'Edouard Mendy', '→ Champions League via league finish']
# [4, 'Tottenham', '38', '22', '5', '11', '69', '40', '+29', '71', '1.87', '66.5', '45.3', '+21.2', '+0.56', '56,523', 'Son Heung-min - 23', 'Hugo Lloris', '→ Champions League via league finish']
# [5, 'Arsenal', '38', '22', '3', '13', '61', '48', '+13', '69', '1.82', '67.3', '51.2', '+16.0', '+0.42', '59,665', 'Bukayo Saka - 11', 'Aaron Ramsdale', '→ Europa League via league finish']
# [6, 'Manchester Utd', '38', '16', '10', '12', '57', '57', '0', '58', '1.53', '61.7', '59.6', '+2.1', '+0.05', '73,150', 'Cristiano Ronaldo - 18', 'David de Gea', '→ Europa League via league finish']
# [7, 'West Ham', '38', '16', '8', '14', '60', '51', '+9', '56', '1.47', '58.0', '58.1', '0.0', '0.00', '58,370', 'Jarrod Bowen - 12', 'Łukasz Fabiański', '→ Europa Conference League via league finish']
# [8, 'Leicester City', '38', '14', '10', '14', '62', '59', '+3', '52', '1.37', '52.1', '68.8', '-16.7', '-0.44', '32,493', 'Jamie Vardy - 15', 'Kasper Schmeichel', '']
# [9, 'Brighton', '38', '12', '15', '11', '42', '44', '-2', '51', '1.34', '53.0', '49.8', '+3.2', '+0.08', '30,966', 'Leandro Trossard, Neal Maupay - 8', 'Robert Sánchez', '']
# [10, 'Wolves', '38', '15', '6', '17', '38', '43', '-5', '51', '1.34', '41.2', '63.7', '-22.5', '-0.59', '30,841', 'Raúl Jiménez - 6', 'José Sá', '']
# [11, 'Newcastle Utd', '38', '13', '10', '15', '44', '62', '-18', '49', '1.29', '44.4', '62.4', '-18.0', '-0.47', '51,487', 'Callum Wilson - 8', 'Martin Dúbravka', '']
# [12, 'Crystal Palace', '38', '11', '15', '12', '50', '46', '+4', '48', '1.26', '53.8', '46.0', '+7.8', '+0.21', '24,588', 'Wilfried Zaha - 14', 'Vicente Guaita', '']
# [13, 'Brentford', '38', '13', '7', '18', '48', '56', '-8', '46', '1.21', '51.1', '54.0', '-2.8', '-0.07', '16,918', 'Ivan Toney - 12', 'David Raya', '']
# [14, 'Aston Villa', '38', '13', '6', '19', '52', '54', '-2', '45', '1.18', '47.9', '54.4', '-6.5', '-0.17', '41,681', 'Ollie Watkins - 11', 'Emiliano Martínez', '']
# [15, 'Southampton', '38', '9', '13', '16', '43', '67', '-24', '40', '1.05', '49.9', '63.3', '-13.4', '-0.35', '30,134', 'James Ward-Prowse - 10', 'Fraser Forster', '']
# [16, 'Everton', '38', '11', '6', '21', '43', '66', '-23', '39', '1.03', '47.5', '60.9', '-13.4', '-0.35', '38,446', 'Richarlison - 10', 'Jordan Pickford', '']
# [17, 'Leeds United', '38', '9', '11', '18', '42', '79', '-37', '38', '1.00', '50.4', '73.2', '-22.8', '-0.60', '36,308', 'Raphinha - 11', 'Illan Meslier', '']
# [18, 'Burnley', '38', '7', '14', '17', '34', '53', '-19', '35', '0.92', '43.8', '63.8', '-20.0', '-0.53', '19,278', 'Maxwel Cornet - 9', 'Nick Pope', 'Relegated']
# [19, 'Watford', '38', '6', '5', '27', '34', '77', '-43', '23', '0.61', '44.3', '72.6', '-28.2', '-0.74', '20,614', 'Emmanuel Dennis - 10', 'Ben Foster', 'Relegated']
# [20, 'Norwich City', '38', '5', '7', '26', '23', '84', '-61', '22', '0.58', '35.7', '82.3', '-46.6', '-1.23', '26,836', 'Teemu Pukki - 11', 'Tim Krul', 'Relegated']

# %%
df
# Out:
#     Rk            Squad  MP   W   D   L  GF  GA   GD Pts Pts/MP    xG   xGA  \
# 0    1  Manchester City  38  29   6   3  99  26  +73  93   2.45  96.6  26.0
# 1    2        Liverpool  38  28   8   2  94  26  +68  92   2.42  95.1  37.3
# 2    3          Chelsea  38  21  11   6  76  33  +43  74   1.95  70.7  38.3
# 3    4        Tottenham  38  22   5  11  69  40  +29  71   1.87  66.5  45.3
# 4    5          Arsenal  38  22   3  13  61  48  +13  69   1.82  67.3  51.2
# 5    6   Manchester Utd  38  16  10  12  57  57    0  58   1.53  61.7  59.6
# 6    7         West Ham  38  16   8  14  60  51   +9  56   1.47  58.0  58.1
# 7    8   Leicester City  38  14  10  14  62  59   +3  52   1.37  52.1  68.8
# 8    9         Brighton  38  12  15  11  42  44   -2  51   1.34  53.0  49.8
# 9   10           Wolves  38  15   6  17  38  43   -5  51   1.34  41.2  63.7
# 10  11    Newcastle Utd  38  13  10  15  44  62  -18  49   1.29  44.4  62.4
# 11  12   Crystal Palace  38  11  15  12  50  46   +4  48   1.26  53.8  46.0
# 12  13        Brentford  38  13   7  18  48  56   -8  46   1.21  51.1  54.0
# 13  14      Aston Villa  38  13   6  19  52  54   -2  45   1.18  47.9  54.4
# 14  15      Southampton  38   9  13  16  43  67  -24  40   1.05  49.9  63.3
# 15  16          Everton  38  11   6  21  43  66  -23  39   1.03  47.5  60.9
# 16  17     Leeds United  38   9  11  18  42  79  -37  38   1.00  50.4  73.2
# 17  18          Burnley  38   7  14  17  34  53  -19  35   0.92  43.8  63.8
# 18  19          Watford  38   6   5  27  34  77  -43  23   0.61  44.3  72.6
# 19  20     Norwich City  38   5   7  26  23  84  -61  22   0.58  35.7  82.3
#
#       xGD xGD/90 Attendance                    Top Team Scorer  \
# 0   +70.5  +1.86     52,774               Kevin De Bruyne - 15
# 1   +57.8  +1.52     53,352                 Mohamed Salah - 23
# 2   +32.5  +0.86     36,443                   Mason Mount - 11
# 3   +21.2  +0.56     56,523                 Son Heung-min - 23
# 4   +16.0  +0.42     59,665                   Bukayo Saka - 11
# 5    +2.1  +0.05     73,150             Cristiano Ronaldo - 18
# 6     0.0   0.00     58,370                  Jarrod Bowen - 12
# 7   -16.7  -0.44     32,493                   Jamie Vardy - 15
# 8    +3.2  +0.08     30,966  Leandro Trossard, Neal Maupay - 8
# 9   -22.5  -0.59     30,841                   Raúl Jiménez - 6
# 10  -18.0  -0.47     51,487                  Callum Wilson - 8
# 11   +7.8  +0.21     24,588                 Wilfried Zaha - 14
# 12   -2.8  -0.07     16,918                    Ivan Toney - 12
# 13   -6.5  -0.17     41,681                 Ollie Watkins - 11
# 14  -13.4  -0.35     30,134             James Ward-Prowse - 10
# 15  -13.4  -0.35     38,446                   Richarlison - 10
# 16  -22.8  -0.60     36,308                      Raphinha - 11
# 17  -20.0  -0.53     19,278                  Maxwel Cornet - 9
# 18  -28.2  -0.74     20,614               Emmanuel Dennis - 10
# 19  -46.6  -1.23     26,836                   Teemu Pukki - 11
#
#            Goalkeeper                                         Notes
# 0             Ederson          → Champions League via league finish
# 1             Alisson          → Champions League via league finish
# 2       Edouard Mendy          → Champions League via league finish
# 3         Hugo Lloris          → Champions League via league finish
# 4      Aaron Ramsdale             → Europa League via league finish
# 5        David de Gea             → Europa League via league finish
# 6    Łukasz Fabiański  → Europa Conference League via league finish
# 7   Kasper Schmeichel
# 8      Robert Sánchez
# 9             José Sá
# 10    Martin Dúbravka
# 11     Vicente Guaita
# 12         David Raya
# 13  Emiliano Martínez
# 14     Fraser Forster
# 15    Jordan Pickford
# 16      Illan Meslier
# 17          Nick Pope                                     Relegated
# 18         Ben Foster                                     Relegated
# 19           Tim Krul                                     Relegated

# %% [markdown]
# cleaning the data to convert the data to numeric type whilst ignoring the errors

# %%
df[df.columns] = df[df.columns].apply(pd.to_numeric,errors='ignore')
df
# Out:
#     Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1  Manchester City  38  29   6   3  99  26  73   93    2.45  96.6  26.0
# 1    2        Liverpool  38  28   8   2  94  26  68   92    2.42  95.1  37.3
# 2    3          Chelsea  38  21  11   6  76  33  43   74    1.95  70.7  38.3
# 3    4        Tottenham  38  22   5  11  69  40  29   71    1.87  66.5  45.3
# 4    5          Arsenal  38  22   3  13  61  48  13   69    1.82  67.3  51.2
# 5    6   Manchester Utd  38  16  10  12  57  57   0   58    1.53  61.7  59.6
# 6    7         West Ham  38  16   8  14  60  51   9   56    1.47  58.0  58.1
# 7    8   Leicester City  38  14  10  14  62  59   3   52    1.37  52.1  68.8
# 8    9         Brighton  38  12  15  11  42  44  -2   51    1.34  53.0  49.8
# 9   10           Wolves  38  15   6  17  38  43  -5   51    1.34  41.2  63.7
# 10  11    Newcastle Utd  38  13  10  15  44  62 -18   49    1.29  44.4  62.4
# 11  12   Crystal Palace  38  11  15  12  50  46   4   48    1.26  53.8  46.0
# 12  13        Brentford  38  13   7  18  48  56  -8   46    1.21  51.1  54.0
# 13  14      Aston Villa  38  13   6  19  52  54  -2   45    1.18  47.9  54.4
# 14  15      Southampton  38   9  13  16  43  67 -24   40    1.05  49.9  63.3
# 15  16          Everton  38  11   6  21  43  66 -23   39    1.03  47.5  60.9
# 16  17     Leeds United  38   9  11  18  42  79 -37   38    1.00  50.4  73.2
# 17  18          Burnley  38   7  14  17  34  53 -19   35    0.92  43.8  63.8
# 18  19          Watford  38   6   5  27  34  77 -43   23    0.61  44.3  72.6
# 19  20     Norwich City  38   5   7  26  23  84 -61   22    0.58  35.7  82.3
#
#      xGD  xGD/90 Attendance                    Top Team Scorer  \
# 0   70.5    1.86     52,774               Kevin De Bruyne - 15
# 1   57.8    1.52     53,352                 Mohamed Salah - 23
# 2   32.5    0.86     36,443                   Mason Mount - 11
# 3   21.2    0.56     56,523                 Son Heung-min - 23
# 4   16.0    0.42     59,665                   Bukayo Saka - 11
# 5    2.1    0.05     73,150             Cristiano Ronaldo - 18
# 6    0.0    0.00     58,370                  Jarrod Bowen - 12
# 7  -16.7   -0.44     32,493                   Jamie Vardy - 15
# 8    3.2    0.08     30,966  Leandro Trossard, Neal Maupay - 8
# 9  -22.5   -0.59     30,841                   Raúl Jiménez - 6
# 10 -18.0   -0.47     51,487                  Callum Wilson - 8
# 11   7.8    0.21     24,588                 Wilfried Zaha - 14
# 12  -2.8   -0.07     16,918                    Ivan Toney - 12
# 13  -6.5   -0.17     41,681                 Ollie Watkins - 11
# 14 -13.4   -0.35     30,134             James Ward-Prowse - 10
# 15 -13.4   -0.35     38,446                   Richarlison - 10
# 16 -22.8   -0.60     36,308                      Raphinha - 11
# 17 -20.0   -0.53     19,278                  Maxwel Cornet - 9
# 18 -28.2   -0.74     20,614               Emmanuel Dennis - 10
# 19 -46.6   -1.23     26,836                   Teemu Pukki - 11
#
#            Goalkeeper                                         Notes
# 0             Ederson          → Champions League via league finish
# 1             Alisson          → Champions League via league finish
# 2       Edouard Mendy          → Champions League via league finish
# 3         Hugo Lloris          → Champions League via league finish
# 4      Aaron Ramsdale             → Europa League via league finish
# 5        David de Gea             → Europa League via league finish
# 6    Łukasz Fabiański  → Europa Conference League via league finish
# 7   Kasper Schmeichel
# 8      Robert Sánchez
# 9             José Sá
# 10    Martin Dúbravka
# 11     Vicente Guaita
# 12         David Raya
# 13  Emiliano Martínez
# 14     Fraser Forster
# 15    Jordan Pickford
# 16      Illan Meslier
# 17          Nick Pope                                     Relegated
# 18         Ben Foster                                     Relegated
# 19           Tim Krul                                     Relegated

# %% [markdown]
# Using the scraper to collect data

# %%
url="https://fbref.com/en/comps/9/{0}/{0}-Premier-League-Stats"

df202122=scrape(url.format("2021-2022"))
df202021=scrape(url.format("2020-2021"))
df201920=scrape(url.format("2019-2020"))
df201819=scrape(url.format("2018-2019"))
# Out:
# [1, 'Manchester City', '38', '29', '6', '3', '99', '26', '+73', '93', '2.45', '96.6', '26.0', '+70.5', '+1.86', '52,774', 'Kevin De Bruyne - 15', 'Ederson', '→ Champions League via league finish']
# [2, 'Liverpool', '38', '28', '8', '2', '94', '26', '+68', '92', '2.42', '95.1', '37.3', '+57.8', '+1.52', '53,352', 'Mohamed Salah - 23', 'Alisson', '→ Champions League via league finish']
# [3, 'Chelsea', '38', '21', '11', '6', '76', '33', '+43', '74', '1.95', '70.7', '38.3', '+32.5', '+0.86', '36,443', 'Mason Mount - 11', 'Edouard Mendy', '→ Champions League via league finish']
# [4, 'Tottenham', '38', '22', '5', '11', '69', '40', '+29', '71', '1.87', '66.5', '45.3', '+21.2', '+0.56', '56,523', 'Son Heung-min - 23', 'Hugo Lloris', '→ Champions League via league finish']
# [5, 'Arsenal', '38', '22', '3', '13', '61', '48', '+13', '69', '1.82', '67.3', '51.2', '+16.0', '+0.42', '59,665', 'Bukayo Saka - 11', 'Aaron Ramsdale', '→ Europa League via league finish']
# [6, 'Manchester Utd', '38', '16', '10', '12', '57', '57', '0', '58', '1.53', '61.7', '59.6', '+2.1', '+0.05', '73,150', 'Cristiano Ronaldo - 18', 'David de Gea', '→ Europa League via league finish']
# [7, 'West Ham', '38', '16', '8', '14', '60', '51', '+9', '56', '1.47', '58.0', '58.1', '0.0', '0.00', '58,370', 'Jarrod Bowen - 12', 'Łukasz Fabiański', '→ Europa Conference League via league finish']
# [8, 'Leicester City', '38', '14', '10', '14', '62', '59', '+3', '52', '1.37', '52.1', '68.8', '-16.7', '-0.44', '32,493', 'Jamie Vardy - 15', 'Kasper Schmeichel', '']
# [9, 'Brighton', '38', '12', '15', '11', '42', '44', '-2', '51', '1.34', '53.0', '49.8', '+3.2', '+0.08', '30,966', 'Leandro Trossard, Neal Maupay - 8', 'Robert Sánchez', '']
# [10, 'Wolves', '38', '15', '6', '17', '38', '43', '-5', '51', '1.34', '41.2', '63.7', '-22.5', '-0.59', '30,841', 'Raúl Jiménez - 6', 'José Sá', '']
# [11, 'Newcastle Utd', '38', '13', '10', '15', '44', '62', '-18', '49', '1.29', '44.4', '62.4', '-18.0', '-0.47', '51,487', 'Callum Wilson - 8', 'Martin Dúbravka', '']
# [12, 'Crystal Palace', '38', '11', '15', '12', '50', '46', '+4', '48', '1.26', '53.8', '46.0', '+7.8', '+0.21', '24,588', 'Wilfried Zaha - 14', 'Vicente Guaita', '']
# [13, 'Brentford', '38', '13', '7', '18', '48', '56', '-8', '46', '1.21', '51.1', '54.0', '-2.8', '-0.07', '16,918', 'Ivan Toney - 12', 'David Raya', '']
# [14, 'Aston Villa', '38', '13', '6', '19', '52', '54', '-2', '45', '1.18', '47.9', '54.4', '-6.5', '-0.17', '41,681', 'Ollie Watkins - 11', 'Emiliano Martínez', '']
# [15, 'Southampton', '38', '9', '13', '16', '43', '67', '-24', '40', '1.05', '49.9', '63.3', '-13.4', '-0.35', '30,134', 'James Ward-Prowse - 10', 'Fraser Forster', '']
# [16, 'Everton', '38', '11', '6', '21', '43', '66', '-23', '39', '1.03', '47.5', '60.9', '-13.4', '-0.35', '38,446', 'Richarlison - 10', 'Jordan Pickford', '']
# [17, 'Leeds United', '38', '9', '11', '18', '42', '79', '-37', '38', '1.00', '50.4', '73.2', '-22.8', '-0.60', '36,308', 'Raphinha - 11', 'Illan Meslier', '']
# [18, 'Burnley', '38', '7', '14', '17', '34', '53', '-19', '35', '0.92', '43.8', '63.8', '-20.0', '-0.53', '19,278', 'Maxwel Cornet - 9', 'Nick Pope', 'Relegated']
# [19, 'Watford', '38', '6', '5', '27', '34', '77', '-43', '23', '0.61', '44.3', '72.6', '-28.2', '-0.74', '20,614', 'Emmanuel Dennis - 10', 'Ben Foster', 'Relegated']
# [20, 'Norwich City', '38', '5', '7', '26', '23', '84', '-61', '22', '0.58', '35.7', '82.3', '-46.6', '-1.23', '26,836', 'Teemu Pukki - 11', 'Tim Krul', 'Relegated']
# [1, 'Manchester City', '38', '27', '5', '6', '83', '32', '+51', '86', '2.26', '68.2', '30.2', '+38.0', '+1.00', '526', 'İlkay Gündoğan - 13', 'Ederson', '→ Champions League via league finish']
# [2, 'Manchester Utd', '38', '21', '11', '6', '73', '44', '+29', '74', '1.95', '60.1', '41.5', '+18.6', '+0.49', '526', 'Bruno Fernandes - 18', 'David de Gea', '→ Champions League via league finish']
# [3, 'Liverpool', '38', '20', '9', '9', '68', '42', '+26', '69', '1.82', '67.5', '43.0', '+24.5', '+0.65', '837', 'Mohamed Salah - 22', 'Alisson', '→ Champions League via league finish']
# [4, 'Chelsea', '38', '19', '10', '9', '58', '36', '+22', '67', '1.76', '62.4', '30.3', '+32.2', '+0.85', '526', 'Jorginho - 7', 'Edouard Mendy', '→ Champions League via league finish']
# [5, 'Leicester City', '38', '20', '6', '12', '68', '50', '+18', '66', '1.74', '55.8', '46.0', '+9.8', '+0.26', '421', 'Jamie Vardy - 15', 'Kasper Schmeichel', '→ Europa League via cup win']
# [6, 'West Ham', '38', '19', '8', '11', '62', '47', '+15', '65', '1.71', '55.4', '48.7', '+6.7', '+0.18', '632', 'Michail Antonio, Tomáš Souček - 10', 'Łukasz Fabiański', '→ Europa League via league finish']
# [7, 'Tottenham', '38', '18', '8', '12', '68', '45', '+23', '62', '1.63', '53.1', '49.1', '+4.0', '+0.10', '632', 'Harry Kane - 23', 'Hugo Lloris', '→ Europa Conference League via league finish 1']
# [8, 'Arsenal', '38', '18', '7', '13', '55', '39', '+16', '61', '1.61', '51.8', '43.0', '+8.8', '+0.23', '632', 'Alexandre Lacazette - 13', 'Bernd Leno', '']
# [9, 'Leeds United', '38', '18', '5', '15', '62', '54', '+8', '59', '1.55', '55.6', '57.9', '-2.2', '-0.06', '421', 'Patrick Bamford - 17', 'Illan Meslier', '']
# [10, 'Everton', '38', '17', '8', '13', '47', '48', '-1', '59', '1.55', '45.7', '50.1', '-4.5', '-0.12', '368', 'Dominic Calvert-Lewin - 16', 'Jordan Pickford', '']
# [11, 'Aston Villa', '38', '16', '7', '15', '55', '46', '+9', '55', '1.45', '52.5', '51.1', '+1.4', '+0.04', '526', 'Ollie Watkins - 14', 'Emiliano Martínez', '']
# [12, 'Newcastle Utd', '38', '12', '9', '17', '46', '62', '-16', '45', '1.18', '43.4', '58.3', '-14.9', '-0.39', '526', 'Callum Wilson - 12', 'Karl Darlow', '']
# [13, 'Wolves', '38', '12', '9', '17', '36', '52', '-16', '45', '1.18', '36.5', '49.5', '-13.0', '-0.34', '237', 'Rúben Neves, Pedro Neto - 5', 'Rui Patrício', '']
# [14, 'Crystal Palace', '38', '12', '8', '18', '41', '66', '-25', '44', '1.16', '34.1', '58.2', '-24.2', '-0.64', '447', 'Wilfried Zaha - 11', 'Vicente Guaita', '']
# [15, 'Southampton', '38', '12', '7', '19', '47', '68', '-21', '43', '1.13', '41.2', '53.1', '-11.8', '-0.31', '526', 'Danny Ings - 12', 'Alex McCarthy', '']
# [16, 'Brighton', '38', '9', '14', '15', '40', '46', '-6', '41', '1.08', '50.9', '35.3', '+15.6', '+0.41', '523', 'Neal Maupay - 8', 'Robert Sánchez', '']
# [17, 'Burnley', '38', '10', '9', '19', '33', '55', '-22', '39', '1.03', '39.3', '54.7', '-15.4', '-0.40', '178', 'Chris Wood - 12', 'Nick Pope', '']
# [18, 'Fulham', '38', '5', '13', '20', '27', '53', '-26', '28', '0.74', '40.5', '52.6', '-12.1', '-0.32', '211', 'Bobby Reid - 5', 'Alphonse Areola', 'Relegated']
# [19, 'West Brom', '38', '5', '11', '22', '35', '76', '-41', '26', '0.68', '35.8', '67.9', '-32.0', '-0.84', '283', 'Matheus Pereira - 11', 'Sam Johnstone', 'Relegated']
# [20, 'Sheffield Utd', '38', '7', '2', '29', '20', '63', '-43', '23', '0.61', '32.6', '62.2', '-29.6', '-0.78', '263', 'David McGoldrick - 8', 'Aaron Ramsdale', 'Relegated']
# [1, 'Liverpool', '38', '32', '3', '3', '85', '33', '+52', '99', '2.61', '68.9', '37.7', '+31.2', '+0.82', '41,955', 'Mohamed Salah - 19', 'Alisson', '→ Champions League via league finish']
# [2, 'Manchester City', '38', '26', '3', '9', '102', '35', '+67', '81', '2.13', '92.0', '36.2', '+55.7', '+1.47', '37,097', 'Raheem Sterling - 20', 'Ederson', '→ Champions League via league finish']
# [3, 'Manchester Utd', '38', '18', '12', '8', '66', '36', '+30', '66', '1.74', '62.2', '37.7', '+24.5', '+0.64', '57,415', 'Anthony Martial, Marcus Rashford - 17', 'David de Gea', '→ Champions League via league finish']
# [4, 'Chelsea', '38', '20', '6', '12', '69', '54', '+15', '66', '1.74', '69.2', '38.6', '+30.6', '+0.81', '32,023', 'Tammy Abraham - 15', 'Kepa Arrizabalaga', '→ Champions League via league finish']
# [5, 'Leicester City', '38', '18', '8', '12', '67', '41', '+26', '62', '1.63', '62.2', '45.5', '+16.7', '+0.44', '25,312', 'Jamie Vardy - 23', 'Kasper Schmeichel', '→ Europa League via league finish']
# [6, 'Tottenham', '38', '16', '11', '11', '61', '47', '+14', '59', '1.55', '47.9', '54.2', '-6.3', '-0.17', '43,757', 'Harry Kane - 18', 'Hugo Lloris', '→ Europa League via league finish 1']
# [7, 'Wolves', '38', '15', '14', '9', '51', '40', '+11', '59', '1.55', '54.1', '38.0', '+16.1', '+0.42', '24,758', 'Raúl Jiménez - 17', 'Rui Patrício', '']
# [8, 'Arsenal', '38', '14', '14', '10', '56', '48', '+8', '56', '1.47', '47.0', '55.3', '-8.3', '-0.22', '47,589', 'Pierre-Emerick Aubameyang - 22', 'Bernd Leno', '→ Europa League via cup win 2']
# [9, 'Sheffield Utd', '38', '14', '12', '12', '39', '39', '0', '54', '1.42', '43.0', '51.0', '-7.9', '-0.21', '24,370', 'Lys Mousset, Oliver McBurnie - 6', 'Dean Henderson', '']
# [10, 'Burnley', '38', '15', '9', '14', '43', '50', '-7', '54', '1.42', '47.4', '49.8', '-2.4', '-0.06', '15,995', 'Chris Wood - 14', 'Nick Pope', '']
# [11, 'Southampton', '38', '15', '7', '16', '51', '60', '-9', '52', '1.37', '56.1', '52.8', '+3.3', '+0.09', '23,428', 'Danny Ings - 22', 'Alex McCarthy', '']
# [12, 'Everton', '38', '13', '10', '15', '44', '56', '-12', '49', '1.29', '50.8', '48.3', '+2.5', '+0.07', '28,848', 'Dominic Calvert-Lewin, Richarlison - 13', 'Jordan Pickford', '']
# [13, 'Newcastle Utd', '38', '11', '11', '16', '38', '58', '-20', '44', '1.16', '35.5', '65.6', '-30.1', '-0.79', '35,551', 'Jonjo Shelvey - 6', 'Martin Dúbravka', '']
# [14, 'Crystal Palace', '38', '11', '10', '17', '31', '50', '-19', '43', '1.13', '35.8', '57.0', '-21.2', '-0.56', '19,784', 'Jordan Ayew - 9', 'Vicente Guaita', '']
# [15, 'Brighton', '38', '9', '14', '15', '39', '54', '-15', '41', '1.08', '45.4', '55.0', '-9.5', '-0.25', '22,369', 'Neal Maupay - 10', 'Mathew Ryan', '']
# [16, 'West Ham', '38', '10', '9', '19', '49', '62', '-13', '39', '1.03', '48.6', '63.8', '-15.3', '-0.40', '44,155', 'Michail Antonio - 10', 'Łukasz Fabiański', '']
# [17, 'Aston Villa', '38', '9', '8', '21', '41', '67', '-26', '35', '0.92', '44.3', '67.8', '-23.5', '-0.62', '28,505', 'Jack Grealish - 8', 'Tom Heaton', '']
# [18, 'Bournemouth', '38', '9', '7', '22', '40', '65', '-25', '34', '0.89', '44.8', '62.3', '-17.5', '-0.46', '7,745', 'Callum Wilson - 8', 'Aaron Ramsdale', 'Relegated']
# [19, 'Watford', '38', '8', '10', '20', '36', '64', '-28', '34', '0.89', '48.9', '58.1', '-9.3', '-0.24', '15,353', 'Troy Deeney - 10', 'Ben Foster', 'Relegated']
# [20, 'Norwich City', '38', '5', '6', '27', '26', '75', '-49', '21', '0.55', '37.0', '66.4', '-29.5', '-0.78', '19,913', 'Teemu Pukki - 11', 'Tim Krul', 'Relegated']
# [1, 'Manchester City', '38', '32', '2', '4', '95', '23', '+72', '98', '2.58', '84.3', '24.7', '+59.6', '+1.57', '54,130', 'Sergio Agüero - 21', 'Ederson', '→ Champions League via league finish']
# [2, 'Liverpool', '38', '30', '7', '1', '89', '22', '+67', '97', '2.55', '73.7', '28.8', '+44.9', '+1.18', '52,983', 'Sadio Mané, Mohamed Salah - 22', 'Alisson', '→ Champions League via league finish']
# [3, 'Chelsea', '38', '21', '9', '8', '63', '39', '+24', '72', '1.89', '58.6', '36.4', '+22.2', '+0.58', '40,437', 'Eden Hazard - 16', 'Kepa Arrizabalaga', '→ Champions League via league finish']
# [4, 'Tottenham', '38', '23', '2', '13', '67', '39', '+28', '71', '1.87', '54.9', '47.1', '+7.8', '+0.20', '54,216', 'Harry Kane - 17', 'Hugo Lloris', '→ Champions League via league finish']
# [5, 'Arsenal', '38', '21', '7', '10', '73', '51', '+22', '70', '1.84', '60.1', '54.2', '+5.9', '+0.15', '59,899', 'Pierre-Emerick Aubameyang - 22', 'Bernd Leno', '→ Europa League via league finish']
# [6, 'Manchester Utd', '38', '19', '9', '10', '65', '54', '+11', '66', '1.74', '61.4', '50.6', '+10.8', '+0.29', '74,498', 'Paul Pogba - 13', 'David de Gea', '→ Europa League via league finish 1']
# [7, 'Wolves', '38', '16', '9', '13', '47', '46', '+1', '57', '1.50', '52.1', '42.1', '+10.1', '+0.26', '31,030', 'Raúl Jiménez - 13', 'Rui Patrício', '→ Europa League via league finish']
# [8, 'Everton', '38', '15', '9', '14', '54', '46', '+8', '54', '1.42', '49.7', '45.7', '+4.0', '+0.10', '39,043', 'Gylfi Sigurðsson, Richarlison - 13', 'Jordan Pickford', '']
# [9, 'Leicester City', '38', '15', '7', '16', '51', '48', '+3', '52', '1.37', '52.4', '43.7', '+8.7', '+0.23', '31,851', 'Jamie Vardy - 18', 'Kasper Schmeichel', '']
# [10, 'West Ham', '38', '15', '7', '16', '52', '55', '-3', '52', '1.37', '47.6', '61.9', '-14.3', '-0.38', '58,336', 'Marko Arnautović - 10', 'Łukasz Fabiański', '']
# [11, 'Watford', '38', '14', '8', '16', '52', '59', '-7', '50', '1.32', '48.2', '59.2', '-11.0', '-0.29', '20,016', 'Gerard Deulofeu - 10', 'Ben Foster', '']
# [12, 'Crystal Palace', '38', '14', '7', '17', '51', '53', '-2', '49', '1.29', '47.6', '50.1', '-2.5', '-0.07', '25,455', 'Luka Milivojević - 12', 'Vicente Guaita', '']
# [13, 'Newcastle Utd', '38', '12', '9', '17', '42', '48', '-6', '45', '1.18', '39.1', '53.6', '-14.5', '-0.38', '51,121', 'Ayoze Pérez - 12', 'Martin Dúbravka', '']
# [14, 'Bournemouth', '38', '13', '6', '19', '56', '70', '-14', '45', '1.18', '53.3', '57.2', '-3.9', '-0.10', '10,532', 'Callum Wilson - 14', 'Asmir Begović', '']
# [15, 'Burnley', '38', '11', '7', '20', '45', '68', '-23', '40', '1.05', '44.4', '62.1', '-17.7', '-0.47', '20,534', 'Ashley Barnes - 12', 'Tom Heaton, Joe Hart', '']
# [16, 'Southampton', '38', '9', '12', '17', '45', '65', '-20', '39', '1.03', '46.9', '55.1', '-8.2', '-0.22', '30,139', 'Danny Ings, James Ward-Prowse - 7', 'Alex McCarthy', '']
# [17, 'Brighton', '38', '9', '9', '20', '35', '60', '-25', '36', '0.95', '35.3', '59.1', '-23.8', '-0.63', '30,426', 'Glenn Murray - 13', 'Mathew Ryan', '']
# [18, 'Cardiff City', '38', '10', '4', '24', '34', '69', '-35', '34', '0.89', '42.4', '61.5', '-19.1', '-0.50', '31,408', 'Bobby Reid, Víctor Camarasa - 5', 'Neil Etheridge', 'Relegated']
# [19, 'Fulham', '38', '7', '5', '26', '34', '81', '-47', '26', '0.68', '41.3', '68.2', '-26.8', '-0.71', '24,371', 'Aleksandar Mitrović - 11', 'Sergio Rico', 'Relegated']
# [20, 'Huddersfield', '38', '3', '7', '28', '22', '76', '-54', '16', '0.42', '28.8', '60.9', '-32.2', '-0.85', '23,203', 'Karlan Grant - 4', 'Jonas Lössl', 'Relegated']

# %% [markdown]
# Appending the scraped data to create a small dataset

# %%
df1=df202122.copy()
df1=df1.append(df202021)
df1=df1.append(df201920)
df1=df1.append(df201819)

# %%
df1
# Out:
#     Rk            Squad  MP   W   D   L  GF  GA   GD Pts Pts/MP    xG   xGA  \
# 0    1  Manchester City  38  29   6   3  99  26  +73  93   2.45  96.6  26.0
# 1    2        Liverpool  38  28   8   2  94  26  +68  92   2.42  95.1  37.3
# 2    3          Chelsea  38  21  11   6  76  33  +43  74   1.95  70.7  38.3
# 3    4        Tottenham  38  22   5  11  69  40  +29  71   1.87  66.5  45.3
# 4    5          Arsenal  38  22   3  13  61  48  +13  69   1.82  67.3  51.2
# ..  ..              ...  ..  ..  ..  ..  ..  ..  ...  ..    ...   ...   ...
# 15  16      Southampton  38   9  12  17  45  65  -20  39   1.03  46.9  55.1
# 16  17         Brighton  38   9   9  20  35  60  -25  36   0.95  35.3  59.1
# 17  18     Cardiff City  38  10   4  24  34  69  -35  34   0.89  42.4  61.5
# 18  19           Fulham  38   7   5  26  34  81  -47  26   0.68  41.3  68.2
# 19  20     Huddersfield  38   3   7  28  22  76  -54  16   0.42  28.8  60.9
#
#       xGD xGD/90 Attendance                    Top Team Scorer  \
# 0   +70.5  +1.86     52,774               Kevin De Bruyne - 15
# 1   +57.8  +1.52     53,352                 Mohamed Salah - 23
# 2   +32.5  +0.86     36,443                   Mason Mount - 11
# 3   +21.2  +0.56     56,523                 Son Heung-min - 23
# 4   +16.0  +0.42     59,665                   Bukayo Saka - 11
# ..    ...    ...        ...                                ...
# 15   -8.2  -0.22     30,139  Danny Ings, James Ward-Prowse - 7
# 16  -23.8  -0.63     30,426                  Glenn Murray - 13
# 17  -19.1  -0.50     31,408    Bobby Reid, Víctor Camarasa - 5
# 18  -26.8  -0.71     24,371           Aleksandar Mitrović - 11
# 19  -32.2  -0.85     23,203                   Karlan Grant - 4
#
#         Goalkeeper                                 Notes
# 0          Ederson  → Champions League via league finish
# 1          Alisson  → Champions League via league finish
# 2    Edouard Mendy  → Champions League via league finish
# 3      Hugo Lloris  → Champions League via league finish
# 4   Aaron Ramsdale     → Europa League via league finish
# ..             ...                                   ...
# 15   Alex McCarthy
# 16     Mathew Ryan
# 17  Neil Etheridge                             Relegated
# 18     Sergio Rico                             Relegated
# 19     Jonas Lössl                             Relegated
#
# [80 rows x 19 columns]

# %% [markdown]
# Cleaning the data to convert it into numeric type

# %%
df1[df1.columns] = df1[df1.columns].apply(pd.to_numeric,errors='ignore')
df1
# Out:
#     Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1  Manchester City  38  29   6   3  99  26  73   93    2.45  96.6  26.0
# 1    2        Liverpool  38  28   8   2  94  26  68   92    2.42  95.1  37.3
# 2    3          Chelsea  38  21  11   6  76  33  43   74    1.95  70.7  38.3
# 3    4        Tottenham  38  22   5  11  69  40  29   71    1.87  66.5  45.3
# 4    5          Arsenal  38  22   3  13  61  48  13   69    1.82  67.3  51.2
# ..  ..              ...  ..  ..  ..  ..  ..  ..  ..  ...     ...   ...   ...
# 15  16      Southampton  38   9  12  17  45  65 -20   39    1.03  46.9  55.1
# 16  17         Brighton  38   9   9  20  35  60 -25   36    0.95  35.3  59.1
# 17  18     Cardiff City  38  10   4  24  34  69 -35   34    0.89  42.4  61.5
# 18  19           Fulham  38   7   5  26  34  81 -47   26    0.68  41.3  68.2
# 19  20     Huddersfield  38   3   7  28  22  76 -54   16    0.42  28.8  60.9
#
#      xGD  xGD/90 Attendance                    Top Team Scorer  \
# 0   70.5    1.86     52,774               Kevin De Bruyne - 15
# 1   57.8    1.52     53,352                 Mohamed Salah - 23
# 2   32.5    0.86     36,443                   Mason Mount - 11
# 3   21.2    0.56     56,523                 Son Heung-min - 23
# 4   16.0    0.42     59,665                   Bukayo Saka - 11
# ..   ...     ...        ...                                ...
# 15  -8.2   -0.22     30,139  Danny Ings, James Ward-Prowse - 7
# 16 -23.8   -0.63     30,426                  Glenn Murray - 13
# 17 -19.1   -0.50     31,408    Bobby Reid, Víctor Camarasa - 5
# 18 -26.8   -0.71     24,371           Aleksandar Mitrović - 11
# 19 -32.2   -0.85     23,203                   Karlan Grant - 4
#
#         Goalkeeper                                 Notes
# 0          Ederson  → Champions League via league finish
# 1          Alisson  → Champions League via league finish
# 2    Edouard Mendy  → Champions League via league finish
# 3      Hugo Lloris  → Champions League via league finish
# 4   Aaron Ramsdale     → Europa League via league finish
# ..             ...                                   ...
# 15   Alex McCarthy
# 16     Mathew Ryan
# 17  Neil Etheridge                             Relegated
# 18     Sergio Rico                             Relegated
# 19     Jonas Lössl                             Relegated
#
# [80 rows x 19 columns]

# %% [markdown]
# Plotting the xG vs Points and xGD vs points graph and finding out which one correlates to the points more

# %%
sns.scatterplot(data=df1,x="xGD",y="Pts",hue="xGD",palette="crest")

# %%
sns.scatterplot(data=df1,x="xG",y="Pts",hue="xG",palette="crest")

# %%
df1['Pts'].corr(df1['xGD']) > df1['Pts'].corr(df1['xG'])
# Out:
# True

# %% [markdown]
# Assigning the testing and training dataset through the xGD and Pts column

# %%
x=df1['xGD']
y=df1['Pts']
x=x.values.reshape(-1,1)
y=y.values.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=101)

# %%
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.coef_)
# Out:
# [[0.64023274]]

# %%
predictions = lm.predict(x_test)

plt.scatter(x_test, y_test,  color='purple')
plt.plot(x_test, predictions, color='green', linewidth=3)
plt.title("Expected Goal Difference vs Points ")
# Out:
# Text(0.5, 1.0, 'Expected Goal Difference vs Points ')

# %%
lm.score(x,y)
# Out:
# 0.8035138090980103

# %%
df_pred = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': predictions.flatten()})
df_pred
# Out:
#     Actual  Predicted
# 0       72  67.388776
# 1       43  39.602675
# 2       44  37.681977
# 3       45  49.014096
# 4       69  68.861312
# 5       65  57.465169
# 6       74  65.083938
# 7       45  44.852584
# 8       62  55.736540
# 9       86  77.504454
# 10      74  73.983174
# 11      28  45.428793
# 12      38  38.578303
# 13      52  58.745634
# 14      56  53.175609
# 15      61  58.809657
# 16      40  44.596491
# 17      59  63.483357
# 18      44  33.904604
# 19      97  81.922060
# 20      57  59.641960
# 21      71  66.748544
# 22      59  49.142143
# 23      66  68.861312
# 24      45  50.678702
# 25      55  54.071935
# 26      92  90.181062
# 27      26  36.017372
# 28      34  47.221445
# 29      16  32.560115
# 30      66  59.449890
# 31      35  40.370954
# 32      41  47.093398
# 33      52  55.288377
# 34      39  44.596491
# 35      66  60.090123
# 36      23  35.121046
# 37      54  48.117771
# 38      26  32.688161
# 39      23  34.224720

# %% [markdown]
# Plotting the actual and predicted points

# %%
plt.plot(df_pred['Actual'])
plt.plot(df_pred['Predicted'])

# %%
#@title Creating team comparison visualizations: Select the season
seasonlist = ['2021-22','2020-21','2019-20',
              '2018-19']
seasons = widgets.Dropdown(
      options=seasonlist,
      value='2021-22',
      rows=5,
      description='Choose Season',
      layout={'width':'max-content'},
      style={'description_width': 'initial'},
      disabled=False
  )
seasons
# Out:
# Dropdown(description='Choose Season', layout=Layout(width='max-content'), options=('2021-22', '2020-21', '2019…

# %%
#@title Select the team
seasonchoose = {'2021-22':df202122,
                '2020-21':df202021,
                '2019-20':df201920,
                '2018-19':df201819}
seasondf1=seasonchoose[seasons.value].copy()
teamlist=[]
for i in seasondf1['Squad']:
  teamlist.append(i)
teams1 = widgets.Dropdown(
      options=teamlist,
      value=teamlist[0],
      rows=20,
      description='Choose Team',
      layout={'width':'max-content'},
      style={'description_width': 'initial'},
      disabled=False
  )
teams1
# Out:
# Dropdown(description='Choose Team', layout=Layout(width='max-content'), options=('Manchester City', 'Liverpool…

# %%
#@title Select the season
seasonlist = ['2021-22','2020-21','2019-20',
              '2018-19']
seasons2 = widgets.Dropdown(
      options=seasonlist,
      value='2021-22',
      rows=5,
      description='Choose Season',
      layout={'width':'max-content'},
      style={'description_width': 'initial'},
      disabled=False
  )
seasons2
# Out:
# Dropdown(description='Choose Season', layout=Layout(width='max-content'), options=('2021-22', '2020-21', '2019…

# %%
#@title   Select the team
seasonchoose = {'2021-22':df202122,
                '2020-21':df202021,
                '2019-20':df201920,
                '2018-19':df201819}
seasondf2=seasonchoose[seasons2.value].copy()
teamlist=[]
for i in seasondf2['Squad']:
  teamlist.append(i)
teams2 = widgets.Dropdown(
      options=teamlist,
      value=teamlist[0],
      rows=20,
      description='Choose Team',
      layout={'width':'max-content'},
      style={'description_width': 'initial'},
      disabled=False
  )
teams2
# Out:
# Dropdown(description='Choose Team', layout=Layout(width='max-content'), options=('Manchester City', 'Mancheste…

# %%
season1_data=[]
season2_data=[]
for index, rows in seasondf1.iterrows():
    my_list =[rows.Squad,rows.W, rows.D, rows.L,rows.GF,rows.xG,rows.GA,rows.xGA,rows.GD,rows.xGD,rows.Pts]
    season1_data.append(my_list)
for i in range(0,len(season1_data)-1):
  if teams1.value==season1_data[i][0]:
    season1_data=season1_data[i]
    break
season1_data=season1_data[1:]
for i in range(len(season1_data)):
  season1_data[i]=float(season1_data[i])


for index, rows in seasondf2.iterrows():
    my_list =[rows.Squad,rows.W, rows.D, rows.L,rows.GF,rows.xG,rows.GA,rows.xGA,rows.GD,rows.xGD,rows.Pts]
    season2_data.append(my_list)
for i in range(0,len(season2_data)-1):
  if teams2.value==season2_data[i][0]:
    season2_data=season2_data[i]
    break
season2_data=season2_data[1:]
for i in range(len(season2_data)):
  season2_data[i]=float(season2_data[i])

# %%
season2_data
# Out:
# [29.0, 6.0, 3.0, 99.0, 96.6, 26.0, 26.0, 73.0, 70.5, 93.0]

# %%
categories = ['Wins','Draws','Losses','Goals','Expected goals','Goals against','Expected goals against',
              'Goal difference','Expected goal difference','Points']
fig = go.Figure()

fig.add_trace(go.Scatterpolar(
      r=season1_data,
      theta=categories,
      fill="toself",
      name=teams1.value,
      fillcolor="#fe9929", 
      opacity=0.6, 
      line=dict(color="#fe9929")))
fig.add_trace(go.Scatterpolar(
      r=season2_data,
      theta=categories,
      fill='toself',
      name=teams2.value,
      fillcolor="#238443", 
      opacity=0.6, 
      line=dict(color="#238443")))
fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      color='white',
      range=[min(season1_data+season2_data),max(season1_data+season2_data)])),
  showlegend=False,
  paper_bgcolor="#000000",
  font=dict(color='white'))
fig.update_polars(dict(bgcolor="#525252"))
fig.add_annotation(x=0, y=1.25,
            text=teams1.value,
            showarrow=False,
            font_color='#fe9929',
            font_size=40
           )
fig.add_annotation(x=0, y=1.1,
            text=seasons.value,
            showarrow=False,
            font_color='#fe9929',
            font_size=20
           )
fig.add_annotation(x=1, y=1.25,
            text=teams2.value,
            showarrow=False,
            font_color='#238443',
            font_size=40
           )
fig.add_annotation(x=1, y=1.1,
            text=seasons2.value,
            showarrow=False,
            font_color='#238443',
            font_size=20
           )
fig.add_annotation(x=0.5, y=-0.17,
            text="Premier League Team Comparison",
            showarrow=False,
            font_color='#ae017e',
            font_size=30
           )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7fc7fea5-6a20-4e64-bbe6-b69193db1013" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fc7fea5-6a20-4e64-bbe6-b69193db1013")) {                    Plotly.newPlot(                        "7fc7fea5-6a20-4e64-bbe6-b69193db1013",                        [{"fill":"toself","fillcolor":"#fe9929","line":{"color":"#fe9929"},"name":"Manchester Utd","opacity":0.6,"r":[16.0,10.0,12.0,57.0,61.7,57.0,59.6,0.0,2.1,58.0],"theta":["Wins","Draws","Losses","Goals","Expected goals","Goals against","Expected goals against","Goal difference","Expected goal difference","Points"],"type":"scatterpolar"},{"fill":"toself","fillcolor":"#238443","line":{"color":"#238443"},"name":"Manchester City","opacity":0.6,"r":[29.0,6.0,3.0,99.0,96.6,26.0,26.0,73.0,70.5,93.0],"theta":["Wins","Draws","Losses","Goals","Expected goals","Goals against","Expected goals against","Goal difference","Expected goal difference","Points"],"type":"scatterpolar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogra ...
